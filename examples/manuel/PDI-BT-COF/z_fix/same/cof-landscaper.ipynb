# %%
import coflandscaper as cl
# Out:
# /Users/gregorlauter/Documents/PhD/2d-cof-mapper/COF-Landscaper-dev/.venv/lib/python3.12/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
COF_NAME = "PDI-BT-COF-same"
MODE = "both"

# %%
landscape = cl.Landscape()
landscape.run_mode(cof_name=COF_NAME, mode=MODE, show=True, rel_energy_max=None)
# Out:
# Saved: PDI-BT-COF-same/3_PDI-BT-COF-same_landscape/pes_PDI-BT-COF-same_serr_heatmap.png
# Saved: PDI-BT-COF-same/3_PDI-BT-COF-same_landscape/pes_PDI-BT-COF-same_serr_isolines.png
# Saved: PDI-BT-COF-same/3_PDI-BT-COF-same_landscape/pes_PDI-BT-COF-same_incl_heatmap.png
# Saved: PDI-BT-COF-same/3_PDI-BT-COF-same_landscape/pes_PDI-BT-COF-same_incl_isolines.png

# %%
analyzer = cl.AnalyzeStacking()
analyzer.analyze(cof_name=COF_NAME, mode=MODE)
# Out:
# Serrated:
#  ILD (Å)  ILS (Å)  Erel (eV)
#     3.9      0.1        0.0
# Inclined:
#  ILD (Å)  ILS (Å)  Erel (eV)
#     3.9      0.1        0.0

# %%
pxrd = cl.PXRD()
pxrd.plot_sim_vs_exp(
    cof_name=COF_NAME,
    mode=MODE,
    xlim=(1.5, 30.0),
)
# Out:
# 'PDI-BT-COF-same/5_PDI-BT-COF-same_analysis/PDI-BT-COF-same_both.png'
