# %%
import gs as gs

raw_nodes = "raw_nodes_single"
raw_linker = "raw_linker_single"
nodes = "nodes"
linker = "linker"
mode = "single_bond"

gs.prepare_xyz(raw_nodes, nodes, mode)
gs.prepare_xyz(raw_linker, linker, mode)
# Out:
# ['raw_linker_single/2-Benzene.xyz']

# %%
topo = "hcb"
output_folder = "cofs"

gs.build_cof_2d(topo, nodes, linker, output_folder)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 topo = "hcb"
#       2 output_folder = "cofs"
# ----> 4 gs.build_cof_2d(topo, nodes, linker, output_folder)
#
# AttributeError: module 'gs' has no attribute 'build_cof_2d'
